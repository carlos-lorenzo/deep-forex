# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.buffers import RolloutBuffer

from forexgym.utils import Query, CurrencyPair
from forexgym.envs import ContinuousActionEnvironment, DiscreteActionEnvironment
import pandas as pd

# %%
def select_close(df: pd.DataFrame, *args, **kwargs) -> pd.DataFrame:
    
    return pd.DataFrame(df["Close"])

def article_processor(df: pd.DataFrame, *args, **kwargs) -> pd.DataFrame:
    df["x1"] = ((df["Close"] - df["Close"].shift(1) ) / df["Close"]).shift(1) 
    df["x2"] = ((df["High"] - df["High"].shift(1) ) / df["High"]).shift(1) 
    df["x3"] = ((df["Low"] - df["Low"].shift(1) ) / df["Low"]).shift(1) 
    df["x4"] = (df["High"] - df["Close"]) / df["Close"] 
    df["x5"] = (df["Close"] - df["Low"]) / df["Close"]
    df["x6"] = df['Close'].ewm(span=26, adjust=False).mean()
    
    return df.drop(["Open", "High", "Low", "Close", "Date"], axis=1)

# %%
#timeframes = ["1m", "5m", "15m", "30m", "1H", "4H", "1D"]
timeframes = ["15m", "1H"]

query = Query(episode_length=256, trading_timeframe="15m", trading_column="Close", lookback=10)

query.add_query(
    timeframe="15m",
    window_size=16,
    data_processor=article_processor
)
query.add_query(
    timeframe="1H",
    window_size=4,
    data_processor=article_processor
)

print(query.observation_size)

# env = ContinuousActionEnvironment(
#     currency_tickers={
#         "EURUSD": timeframes,
#         "GBPUSD": timeframes
#     },
#     query=query,
#     reward_type="continuous",
#     reward_multiplier=1e3,
#     episode_length=256,
# )
# Out:
# 7

# %%
query.observation_size
# Out:
# 120

# %%
model = PPO("MlpPolicy", env, verbose=1, n_steps=4096, tensorboard_log="runs/", device="cpu", rollout_buffer_class=RolloutBuffer, max_grad_norm=0.5)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000)
# Out:
# Logging to runs/PPO_5
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 256       |
# |    ep_rew_mean     | -0.000443 |
# | time/              |           |
# |    fps             | 1098      |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 4096      |
# ----------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.000877     |
# | time/                   |               |
# |    fps                  | 830           |
# |    iterations           | 2             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00037371155 |
# |    clip_fraction        | 0.000415      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.311        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00919       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000223     |
# |    std                  | 1.02          |
# |    value_loss           | 2.33e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000241    |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0010931417 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.376       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00561     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000768    |
# |    std                  | 1.05         |
# |    value_loss           | 2.84e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.000259     |
# | time/                   |               |
# |    fps                  | 767           |
# |    iterations           | 4             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00031959888 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | -0.289        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00599      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -6.09e-05     |
# |    std                  | 1.05          |
# |    value_loss           | 2.38e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000304    |
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 5            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0019261127 |
# |    clip_fraction        | 0.00461      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.302       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00871     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000513    |
# |    std                  | 1.06         |
# |    value_loss           | 2.32e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.000116   |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 6           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.001971144 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.176      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00189    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000939   |
# |    std                  | 1.05        |
# |    value_loss           | 3e-06       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000569    |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 7            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0010982875 |
# |    clip_fraction        | 0.000464     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.222       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00794      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000127    |
# |    std                  | 1.03         |
# |    value_loss           | 2.15e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000126    |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 8            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0016409114 |
# |    clip_fraction        | 0.00769      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.175       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000367    |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000802    |
# |    std                  | 1.05         |
# |    value_loss           | 2.23e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00061     |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 9            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0014963177 |
# |    clip_fraction        | 0.00205      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | -0.198       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00917      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000306    |
# |    std                  | 1.07         |
# |    value_loss           | 2.27e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00095     |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 10           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0018322791 |
# |    clip_fraction        | 0.00471      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | -0.121       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0154      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000776    |
# |    std                  | 1.04         |
# |    value_loss           | 2.5e-06      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.00067    |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 11          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.002748646 |
# |    clip_fraction        | 0.00181     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -0.14       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00953     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000483   |
# |    std                  | 1.04        |
# |    value_loss           | 2.28e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00138     |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 12           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0006421504 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.125       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00388     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.000101     |
# |    std                  | 1.04         |
# |    value_loss           | 2.37e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000743    |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 13           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0014522352 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.124       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0062      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000215    |
# |    std                  | 1.04         |
# |    value_loss           | 2.13e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000587    |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 14           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0028771986 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | -0.162       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0056      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000562    |
# |    std                  | 1.04         |
# |    value_loss           | 1.85e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.000691     |
# | time/                   |               |
# |    fps                  | 727           |
# |    iterations           | 15            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00038455354 |
# |    clip_fraction        | 2.44e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | -0.135        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00547       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -3.48e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.89e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000664    |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 16           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0050068195 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0829      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000987    |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0024      |
# |    std                  | 1.01         |
# |    value_loss           | 2.58e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000674    |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 17           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0031768242 |
# |    clip_fraction        | 0.00667      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.0797      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00393     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000542    |
# |    std                  | 1.01         |
# |    value_loss           | 2.45e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.000685   |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 18          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.000870091 |
# |    clip_fraction        | 0.000562    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.0449     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00305     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000214   |
# |    std                  | 0.987       |
# |    value_loss           | 2.46e-06    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.000765     |
# | time/                   |               |
# |    fps                  | 723           |
# |    iterations           | 19            |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00054734864 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.076        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00315      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -5.88e-05     |
# |    std                  | 1             |
# |    value_loss           | 2.03e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000412    |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 20           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0032258837 |
# |    clip_fraction        | 0.00483      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0758      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000756     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000627    |
# |    std                  | 1            |
# |    value_loss           | 2.21e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.000738   |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 21          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004420733 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.0702     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00687     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.994       |
# |    value_loss           | 2.39e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000351    |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 22           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0044977525 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0591      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00661      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 0.982        |
# |    value_loss           | 2.79e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000236    |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 23           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0021160566 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.0584      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00148      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000877    |
# |    std                  | 0.961        |
# |    value_loss           | 1.73e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | 0.000326    |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 24          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.003931336 |
# |    clip_fraction        | 0.0084      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0506     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000541   |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000943   |
# |    std                  | 0.95        |
# |    value_loss           | 2.3e-06     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | 0.000215    |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 25          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.002137747 |
# |    clip_fraction        | 0.00403     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0865     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00706    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000324   |
# |    std                  | 0.939       |
# |    value_loss           | 1.39e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 0.000309     |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 26           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0016197682 |
# |    clip_fraction        | 0.00283      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0468      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00393      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000121    |
# |    std                  | 0.948        |
# |    value_loss           | 2.06e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 0.00015      |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 27           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0012192687 |
# |    clip_fraction        | 0.00022      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0745      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00543      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 8.15e-06     |
# |    std                  | 0.939        |
# |    value_loss           | 1.64e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 8.49e-05     |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 28           |
# |    time_elapsed         | 158          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0025046645 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.039       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00601      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00159     |
# |    std                  | 0.908        |
# |    value_loss           | 2.11e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000365    |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 29           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0033862274 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.0554      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00894      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00129     |
# |    std                  | 0.9          |
# |    value_loss           | 2.33e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.0006     |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 30          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.000973199 |
# |    clip_fraction        | 0.000391    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.0512     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00372    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -9.39e-06   |
# |    std                  | 0.888       |
# |    value_loss           | 1.92e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00119     |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 31           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0038456465 |
# |    clip_fraction        | 0.00923      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -0.0533      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0187      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000882    |
# |    std                  | 0.887        |
# |    value_loss           | 2.4e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00213     |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 32           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0038944152 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -0.0423      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0242       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000713    |
# |    std                  | 0.883        |
# |    value_loss           | 1.93e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00252     |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 33           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0031524622 |
# |    clip_fraction        | 0.00466      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.0365      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00866      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000616    |
# |    std                  | 0.879        |
# |    value_loss           | 2.53e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.00244      |
# | time/                   |               |
# |    fps                  | 724           |
# |    iterations           | 34            |
# |    time_elapsed         | 192           |
# |    total_timesteps      | 139264        |
# | train/                  |               |
# |    approx_kl            | 0.00065469695 |
# |    clip_fraction        | 0.00061       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | -0.0267       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00295      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000226     |
# |    std                  | 0.902         |
# |    value_loss           | 3.46e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.00266      |
# | time/                   |               |
# |    fps                  | 723           |
# |    iterations           | 35            |
# |    time_elapsed         | 198           |
# |    total_timesteps      | 143360        |
# | train/                  |               |
# |    approx_kl            | 0.00088734576 |
# |    clip_fraction        | 0.0033        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.0378       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000508     |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000634     |
# |    std                  | 0.928         |
# |    value_loss           | 2.51e-06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.00217    |
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 36          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.004396652 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0239     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00822     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.003      |
# |    std                  | 0.925       |
# |    value_loss           | 2.4e-06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.0024      |
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 37           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0020049172 |
# |    clip_fraction        | 0.00173      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.0236      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00186     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -6.73e-05    |
# |    std                  | 0.919        |
# |    value_loss           | 2.12e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.00214    |
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 38          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.001575975 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0359     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000758    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00062    |
# |    std                  | 0.909       |
# |    value_loss           | 2.16e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00171     |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 39           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0036816173 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.0229      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00398      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00126     |
# |    std                  | 0.909        |
# |    value_loss           | 2.56e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00218     |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 40           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0021881766 |
# |    clip_fraction        | 0.00164      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.0204      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00615      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000167    |
# |    std                  | 0.899        |
# |    value_loss           | 2.36e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.0021      |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 41           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0045915022 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -0.0349      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00696     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 0.886        |
# |    value_loss           | 1.68e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00202     |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 42           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0012364337 |
# |    clip_fraction        | 0.000659     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.0291      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00203     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000124    |
# |    std                  | 0.877        |
# |    value_loss           | 2.07e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.00214      |
# | time/                   |               |
# |    fps                  | 720           |
# |    iterations           | 43            |
# |    time_elapsed         | 244           |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 0.00080179714 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | -0.0228       |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00296      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000156     |
# |    std                  | 0.859         |
# |    value_loss           | 3.01e-06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.0017      |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 44           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0033042007 |
# |    clip_fraction        | 0.00588      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.0331      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0013      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000443    |
# |    std                  | 0.854        |
# |    value_loss           | 2.26e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.00107    |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 45          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.001356679 |
# |    clip_fraction        | 0.00544     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.0338     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00472    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000428   |
# |    std                  | 0.843       |
# |    value_loss           | 1.87e-06    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 256        |
# |    ep_rew_mean          | -0.00101   |
# | time/                   |            |
# |    fps                  | 720        |
# |    iterations           | 46         |
# |    time_elapsed         | 261        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.00432189 |
# |    clip_fraction        | 0.0249     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | -0.0212    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00114   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00221   |
# |    std                  | 0.839      |
# |    value_loss           | 1.99e-06   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.000508     |
# | time/                   |               |
# |    fps                  | 719           |
# |    iterations           | 47            |
# |    time_elapsed         | 267           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 0.00079237134 |
# |    clip_fraction        | 0.00139       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.26         |
# |    explained_variance   | -0.0312       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00221       |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000412     |
# |    std                  | 0.863         |
# |    value_loss           | 2.41e-06      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 256        |
# |    ep_rew_mean          | -0.000285  |
# | time/                   |            |
# |    fps                  | 718        |
# |    iterations           | 48         |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.00153774 |
# |    clip_fraction        | 0.000562   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | -0.0301    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00998   |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -4.83e-05  |
# |    std                  | 0.87       |
# |    value_loss           | 1.92e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 256        |
# |    ep_rew_mean          | -3.91e-05  |
# | time/                   |            |
# |    fps                  | 717        |
# |    iterations           | 49         |
# |    time_elapsed         | 279        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.00315979 |
# |    clip_fraction        | 0.00967    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | -0.0319    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00387   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.000745  |
# |    std                  | 0.861      |
# |    value_loss           | 1.84e-06   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | 1.32e-05    |
# | time/                   |             |
# |    fps                  | 717         |
# |    iterations           | 50          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.004391674 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.0244     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00325    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00177    |
# |    std                  | 0.851       |
# |    value_loss           | 1.5e-06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000165    |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 51           |
# |    time_elapsed         | 291          |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0013933098 |
# |    clip_fraction        | 0.00186      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.0333      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00021     |
# |    std                  | 0.85         |
# |    value_loss           | 2.02e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 0.000139     |
# | time/                   |              |
# |    fps                  | 717          |
# |    iterations           | 52           |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0009498931 |
# |    clip_fraction        | 0            |
# ...
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 4.15e-05     |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 229          |
# |    time_elapsed         | 1292         |
# |    total_timesteps      | 937984       |
# | train/                  |              |
# |    approx_kl            | 0.0010362566 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.558       |
# |    explained_variance   | 0.00211      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0144       |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.000184    |
# |    std                  | 0.421        |
# |    value_loss           | 2.31e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 0.000275     |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 230          |
# |    time_elapsed         | 1297         |
# |    total_timesteps      | 942080       |
# | train/                  |              |
# |    approx_kl            | 0.0029036999 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | -0.0019      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0169      |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.418        |
# |    value_loss           | 1.3e-06      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.00016    |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 231         |
# |    time_elapsed         | 1303        |
# |    total_timesteps      | 946176      |
# | train/                  |             |
# |    approx_kl            | 0.002669827 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.0028      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00758    |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.000831   |
# |    std                  | 0.419       |
# |    value_loss           | 1.39e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 0.000284     |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 232          |
# |    time_elapsed         | 1309         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0024292236 |
# |    clip_fraction        | 0.00186      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | -0.00344     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000336     |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -9.35e-05    |
# |    std                  | 0.417        |
# |    value_loss           | 2.08e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -5.37e-05    |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 233          |
# |    time_elapsed         | 1315         |
# |    total_timesteps      | 954368       |
# | train/                  |              |
# |    approx_kl            | 0.0041980175 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | -0.00258     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000284     |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.00241     |
# |    std                  | 0.414        |
# |    value_loss           | 1.98e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.00043    |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 234         |
# |    time_elapsed         | 1320        |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.003809574 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | -0.00728    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00862    |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.000859   |
# |    std                  | 0.41        |
# |    value_loss           | 1.69e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000707    |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 235          |
# |    time_elapsed         | 1326         |
# |    total_timesteps      | 962560       |
# | train/                  |              |
# |    approx_kl            | 0.0005359482 |
# |    clip_fraction        | 0.00198      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | -0.00109     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00189     |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -3.73e-05    |
# |    std                  | 0.418        |
# |    value_loss           | 1.82e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000677    |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 236          |
# |    time_elapsed         | 1332         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0029745402 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | -0.000103    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00533     |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.419        |
# |    value_loss           | 1.98e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000648    |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 237          |
# |    time_elapsed         | 1339         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0041240808 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.00276      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.04         |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.00115     |
# |    std                  | 0.416        |
# |    value_loss           | 1.64e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000759    |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 238          |
# |    time_elapsed         | 1344         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0028196438 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | 0.00124      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00917      |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.00123     |
# |    std                  | 0.408        |
# |    value_loss           | 2.74e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00131     |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 239          |
# |    time_elapsed         | 1350         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0012893586 |
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | -0.000772    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0116      |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.000561    |
# |    std                  | 0.396        |
# |    value_loss           | 2.28e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00112     |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 240          |
# |    time_elapsed         | 1356         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0021194133 |
# |    clip_fraction        | 0.00271      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.497       |
# |    explained_variance   | 0.00124      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00897     |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.000116    |
# |    std                  | 0.397        |
# |    value_loss           | 2.61e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00134     |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 241          |
# |    time_elapsed         | 1361         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0035921324 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | -0.000609    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00605      |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.000792    |
# |    std                  | 0.398        |
# |    value_loss           | 1.34e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00185     |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 242          |
# |    time_elapsed         | 1367         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0015822933 |
# |    clip_fraction        | 0.00681      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | 0.000926     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00709     |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.000847    |
# |    std                  | 0.413        |
# |    value_loss           | 2.63e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.00152    |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 243         |
# |    time_elapsed         | 1373        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.002231332 |
# |    clip_fraction        | 0.00225     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.532      |
# |    explained_variance   | 0.000481    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00349     |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | 3.54e-05    |
# |    std                  | 0.411       |
# |    value_loss           | 1.37e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00183     |
# | time/                   |              |
# |    fps                  | 724          |
# |    iterations           | 244          |
# |    time_elapsed         | 1379         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0049161864 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.523       |
# |    explained_variance   | 0.00411      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0155      |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00204     |
# |    std                  | 0.407        |
# |    value_loss           | 1.85e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.000978   |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 245         |
# |    time_elapsed         | 1384        |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.004832584 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | -0.00159    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00935     |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00111    |
# |    std                  | 0.404       |
# |    value_loss           | 2.17e-06    |
# -----------------------------------------

# %%
obs = env.reset()
rewards = 0
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    #vec_env.render()
    # VecEnv resets automatically
    rewards += reward
    if done:
        obs = env.reset()

env.close()

# %%
obs, info = env.reset()
terminated = False
rewards = 0
while not terminated:
    action = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action[0])
    rewards += reward
    print(reward)
    
print(info)
# Out:
# 0.0009200000000000319
# 0.0003799999999998249
# 0.00024000000000001798
# 0.00038999999999989043
# 0.00042000000000008697
# 0.00031000000000003247
# 0.00042999999999993044
# 0.00045999999999990493
# 0.00019999999999997797
# 0.00024000000000001798
# 0.0006199999999998429
# 0.000140000000000029
# 0.0006099999999999994
# 0.001140000000000141
# 0.000520000000000076
# 0.00038000000000004697
# 0.0001900000000001345
# 7.00000000000145e-05
# 0.0004899999999998794
# 0.0001900000000001345
# 0.0001500000000000945
# 8.999999999992347e-05
