# %%
import gymnasium as gym

from stable_baselines3 import PPO

from forexgym.utils import Query, CurrencyPair
from forexgym.envs import ContinuousActionEnvironment, DiscreteActionEnvironment
import pandas as pd

# %%
def select_close(df: pd.DataFrame, *args, **kwargs) -> pd.DataFrame:
    
    return pd.DataFrame(df["Close"])

def article_processor(df: pd.DataFrame, *args, **kwargs) -> pd.DataFrame:
    df["x1"] = ((df["Close"] - df["Close"].shift(1) ) / df["Close"]).shift(1) 
    df["x2"] = ((df["High"] - df["High"].shift(1) ) / df["High"]).shift(1) 
    df["x3"] = ((df["Low"] - df["Low"].shift(1) ) / df["Low"]).shift(1) 
    df["x4"] = (df["High"] - df["Close"]) / df["Close"] 
    df["x5"] = (df["Close"] - df["Low"]) / df["Close"] 
    
    return df.drop(["Open", "High", "Low", "Close", "Date", "Volume"], axis=1)

# %%
#timeframes = ["1m", "5m", "15m", "30m", "1H", "4H", "1D"]
timeframes = ["15m", "1H"]

query = Query(episode_length=256, trading_timeframe="15m", trading_column="Close")

query.add_query(
    timeframe="15m",
    window_size=16,
    data_processor=article_processor
)
query.add_query(
    timeframe="1H",
    window_size=4,
    data_processor=article_processor
)

env = ContinuousActionEnvironment(
    currency_tickers={
        "EURUSD": timeframes,
        "GBPUSD": timeframes
    },
    query=query,
    reward_type="continuous",
    reward_multiplier=1e3,
    episode_length=256,
)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 31.75it/s]
# Generated EURUSD dataset.
# 100%|██████████| 2/2 [00:00<00:00, 29.41it/s]
# Generated GBPUSD dataset.

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="runs/", device="cpu")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000)
# Out:
# Logging to runs/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 256      |
# |    ep_rew_mean     | -0.00165 |
# | time/              |          |
# |    fps             | 1042     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.0016      |
# | time/                   |              |
# |    fps                  | 833          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 4.480235e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.293       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00128     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -9.14e-06    |
# |    std                  | 0.994        |
# |    value_loss           | 2.34e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000631    |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 5.882964e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.37        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00188     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -1.35e-05    |
# |    std                  | 0.986        |
# |    value_loss           | 3.21e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00076     |
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0006983784 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.335       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00549     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000926    |
# |    std                  | 1.01         |
# |    value_loss           | 3.16e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000779    |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 5            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0043417234 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.361       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0131       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0023      |
# |    std                  | 1            |
# |    value_loss           | 2.27e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000677    |
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 6            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0052313134 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.184       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00385      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00247     |
# |    std                  | 0.998        |
# |    value_loss           | 4.59e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.000525   |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004795951 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.244      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00844     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00256    |
# |    std                  | 0.989       |
# |    value_loss           | 2.56e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000147    |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 8            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0027726514 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.276       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00168      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000618    |
# |    std                  | 0.998        |
# |    value_loss           | 2.66e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000599    |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 9            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0037660636 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.243       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00502      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 1            |
# |    value_loss           | 2.3e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00052     |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 10           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0012691683 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.244       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0102      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00028     |
# |    std                  | 0.998        |
# |    value_loss           | 2.98e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000546    |
# | time/                   |              |
# |    fps                  | 745          |
# |    iterations           | 11           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 9.555495e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.127       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00154      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 3.65e-05     |
# |    std                  | 1            |
# |    value_loss           | 3.97e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000747    |
# | time/                   |              |
# |    fps                  | 747          |
# |    iterations           | 12           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0006952225 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.203       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00346     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000169    |
# |    std                  | 1.01         |
# |    value_loss           | 2.2e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000607    |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 13           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0028164778 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.119       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00714      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 1            |
# |    value_loss           | 3.47e-06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 256           |
# |    ep_rew_mean          | -0.000314     |
# | time/                   |               |
# |    fps                  | 748           |
# |    iterations           | 14            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00022322603 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -0.176        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000985     |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000136     |
# |    std                  | 1.02          |
# |    value_loss           | 2.63e-06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.000728   |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005270906 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -0.152      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0133      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00165    |
# |    std                  | 1.02        |
# |    value_loss           | 2.7e-06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00104     |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 16           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0028846567 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -0.116       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00389     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 1            |
# |    value_loss           | 3.1e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.00104     |
# | time/                   |              |
# |    fps                  | 750          |
# |    iterations           | 17           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0021343818 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00411     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000782    |
# |    std                  | 0.997        |
# |    value_loss           | 2.6e-06      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | -0.000938   |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 18          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005750507 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.179      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.007      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00156    |
# |    std                  | 0.988       |
# |    value_loss           | 2.49e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -0.000814    |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 19           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0023513022 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.172       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00157     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000115    |
# |    std                  | 0.981        |
# |    value_loss           | 1.39e-06     |
# ------------------------------------------

# %%
obs = env.reset()
rewards = 0
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    #vec_env.render()
    # VecEnv resets automatically
    rewards += reward
    if done:
        obs = env.reset()

env.close()

# %%
obs, info = env.reset()
terminated = False
rewards = 0
while not terminated:
    action = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action[0])
    rewards += reward
    print(reward)
    
print(info)
# Out:
# 0.0009200000000000319
# 0.0003799999999998249
# 0.00024000000000001798
# 0.00038999999999989043
# 0.00042000000000008697
# 0.00031000000000003247
# 0.00042999999999993044
# 0.00045999999999990493
# 0.00019999999999997797
# 0.00024000000000001798
# 0.0006199999999998429
# 0.000140000000000029
# 0.0006099999999999994
# 0.001140000000000141
# 0.000520000000000076
# 0.00038000000000004697
# 0.0001900000000001345
# 7.00000000000145e-05
# 0.0004899999999998794
# 0.0001900000000001345
# 0.0001500000000000945
# 8.999999999992347e-05
# 0.0003799999999998249
# 0.00043999999999999595
# 0.00017000000000000348
# 8.999999999992347e-05
# 0.00031000000000003247
# 0.00042999999999993044
# 0.00018999999999991246
# 2.999999999997449e-05
